# %% [markdown]
# <a href="https://colab.research.google.com/github/ezio341/PCVK_Genap_20-21/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
from skimage import 
import random as rd

img = cv.imread('/content/drive/MyDrive/Kitten1.jpg')
img_2 = cv.imread('/content/drive/MyDrive/Kitten2.jpg')
img_2 = cv.cvtColor(img_2, cv.COLOR_BGR2RGB)
img_3 = cv.imread('/content/drive/MyDrive/Kitten3.jpg')
img_3 = cv.cvtColor(img_3, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# Read and store image in BGR channel

# %%
img2 = img
img3 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# Display grayscale, resizeing, flipping, and store image result

# %%
img_gray = cv.imread('/content/drive/MyDrive/Kitten1.jpg', 
                     cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Display grayscale image with gray color map

# %%
plt.imshow(img_gray, cmap = 'gray')

# %% [markdown]
# Display grayscale image with magma color map

# %%
plt.imshow(img_gray, cmap = 'magma')

# %% [markdown]
# Resize the RGB image to 512 x 1024

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), 
                 (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Display RGB image with larger size and flipped vertically

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#store image file

#Display plot with larger canvas size
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Make 2D Geometry from OpenCV. Begin with making of black image with int16 data type.

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Then add rectangle from point pt1(384, 0) to pt2(510, 150). *pt(x, y)

# %%
cv.rectangle(black_img, pt1 = (384, 0), pt2 = (510, 150), 
             color = (0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Then add rectangle from point pt1(200,200) to pt2(300,300)

# %%
cv.rectangle(black_img, pt1 = (200, 200), pt2 = (300, 300), 
             color = (0,0,255), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Then add circle shape with 50 radius and center point at pt(100,100)

# %%
cv.circle(black_img, center = (100,100), radius = 50, 
          color = (255,0,0), thickness = 8)
plt.imshow(black_img)

# %% [markdown]
# Then add line from point pt(0,0) to pt(512, 512)

# %%
cv.line(black_img, pt1 = (0,0), pt2 = (512, 512), 
        color = (255,255,255), thickness = 5)
plt.imshow(black_img)

# %% [markdown]
# Add text with specified size and style

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text = 'hello', org=(10,500), fontFace = font,
           fontScale = 4, color = (255,255,0), thickness = 2,
           lineType = cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Make black image with int32 data type

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# The following codes are use for numpy array initialization with int32 data type

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], 
                    dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Then reshape the array

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Add polyline in the second black image

# %%
cv.polylines(black_img2, [pts], isClosed=True, 
             color=(255,0,0), thickness = 5)
plt.imshow(black_img2)

# %% [markdown]
# Display image with red-green and green-blue channel

# %%
r,g,b = cv.split(img) #get RGB value

for i in range(len(b)):
  cvt_b[i] = 0;
rgimg = cv.merge([r,g,cvt_b])


for i in range(len(r)):
  cvt_r[i] = 0
gbimg = cv.merge([cvt_r, g, b])

fig = plt.figure(figsize=(10,7))
fig.add_subplot(1,2,1)
plt.imshow(rgimg)
plt.title('Red - Green Channel')
fig.add_subplot(1,2,2)
plt.imshow(gbimg)
plt.title('Green - Blue Channel')
# Out:
# Text(0.5, 1.0, 'Green - Blue Channel')

# %% [markdown]
# Display image at (10,10) to (100,100)

# %%
fig = plt.figure(figsize=(10,7))

img_focused = img
cv.rectangle(img_focused, pt1=(10,100), pt2=(100,10), color=[0,0,255], thickness=5)

fig.add_subplot(1,2,1)
plt.imshow(img_focused)
plt.title('original image')

img_crop = img[10:100, 10:100]
fig.add_subplot(1,2,2)
plt.imshow(img_crop)
plt.title('cropped image')
# Out:
# Text(0.5, 1.0, 'cropped image')

# %% [markdown]
# Display the image only row 5-30, and all column, with green channel only

# %%
fig = plt.figure(figsize=(7,7))
img_crop2 = img_2[5:30, 0:len(img[1])]
r,g,b = cv.split(img_crop2)

for m in range(len(r)):
  zero[m] = 0

green_img = cv.merge([zero,g,zero])

fig.add_subplot(2,1,1)
plt.imshow(green_img)
plt.title('cropped image')

fig.add_subplot(2,1,2)
focused_img = cv.rectangle(img_2, pt1=(5, 30), pt2=(len(img_2[1]), 5), 
                           color=(0,0,0), thickness=5)
plt.imshow(focused_img)
plt.title('original image')
# Out:
# Text(0.5, 1.0, 'original image')

# %% [markdown]
# Make 5 rectangle with random size and colour

# %%
rand_rect_img = cv.imread('/content/drive/MyDrive/Kitten3.jpg')
rand_rect_img = cv.cvtColor(rand_rect_img, cv.COLOR_BGR2RGB)

width = rand_rect_img.shape[1]
height = rand_rect_img.shape[0]

for i in range(5):
  rd_height1 = rd.randint(0, height)
  rd_width1 = rd.randint(0, width)
  rd_height2 = rd.randint(0, height)
  rd_width2 = rd.randint(0, width)
  rd_R = rd.randint(0, 255)
  rd_G = rd.randint(0, 255)
  rd_B = rd.randint(0, 255)
  cv.rectangle(rand_rect_img, pt1 = (rd_width1, rd_height1), 
               pt2 = (rd_width2, rd_height2),
               color = (rd_R,rd_G,rd_B), thickness = 10)

plt.imshow(rand_rect_img)

# %% [markdown]
# Display the image with flipped vertically

# %%
flip_img = cv.flip(rand_rect_img, 0)
plt.imshow(flip_img)

# %% [markdown]
# Make a rectangle and circle in the image right on the face

# %%
myphoto = cv.imread('/content/drive/MyDrive/myPhoto.jpg')
myphoto = cv.cvtColor(myphoto, cv.COLOR_BGR2RGB)
myphoto = cv.rectangle(myphoto, pt1=(3400, 600), pt2=(3850, 1200), 
                       color=(255,255,0), thickness=30)
myphoto = cv.circle(myphoto, center=(3625,900), 
                    radius=300, color=(255,0,0), thickness=30)

plt.imshow(myphoto)

# %% [markdown]
# Make rectangle at the left bottom corner with colour channel B at RGB colour space from male person image

# %%
myphoto = cv.imread('/content/drive/MyDrive/myPhoto.jpg')
myphoto = cv.cvtColor(myphoto, cv.COLOR_BGR2RGB)
r,g,b = cv.split(myphoto)

for i in range(len(r)):
  r[i] = 0
  g[i] = 0
myphoto = cv.merge([r,g,b])
myphoto = cv.rectangle(myphoto, pt1=(0,myphoto.shape[0]), 
                       pt2=(300,(myphoto.shape[0]-300)), 
                       color=(255,255,0), thickness=30)

plt.imshow(myphoto)

# %% [markdown]
# Using previous image result, add a text with a certain font style, size, and color

# %%
font = cv.FONT_HERSHEY_COMPLEX 
myphoto = cv.putText(myphoto, 'Hello I\'m Arga', org=(300,300), 
  fontFace=font, fontScale=7, color=(255,255,0), thickness=30) 
plt.imshow(myphoto)
